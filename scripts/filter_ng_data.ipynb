# %%
import pandas as pd
import numpy as np

# %%
#explore cabbage NG data
df = pd.read_csv("/workspace/lab/mcarthurlab/wlodarsm/amr_phenotype_cnn/data/ng_cabbage/amr_portal.csv")
df.head()
# Out:
#   pheno_geno_merged-antibiotic_name pheno_geno_merged-resistance_phenotype  \
# 0                      azithromycin                            susceptible
# 1                      tetracycline                              resistant
# 2                      tetracycline                              resistant
# 3                      tetracycline                              resistant
# 4                      azithromycin                              resistant
#
#   pheno_geno_merged-gen_measurement pheno_geno_merged-BioSample_ID  \
# 0                       == 0.5 mg/L                   SAMN32765978
# 1                        == 32 mg/L                   SAMN32765978
# 2                        == 32 mg/L                   SAMN32765978
# 3                        == 32 mg/L                   SAMN32765978
# 4                          = 8 mg/L                   SAMN04191934
#
#   pheno_geno_merged-assembly_ID pheno_geno_merged-genus  \
# ...

# %%
df.columns
# Out:
# Index(['pheno_geno_merged-antibiotic_name',
#        'pheno_geno_merged-resistance_phenotype',
#        'pheno_geno_merged-gen_measurement', 'pheno_geno_merged-BioSample_ID',
#        'pheno_geno_merged-assembly_ID', 'pheno_geno_merged-genus',
#        'pheno_geno_merged-species', 'pheno_geno_merged-organism',
#        'pheno_geno_merged-taxon_id', 'pheno_geno_merged-host',
#        'pheno_geno_merged-SRA_accession',
#        'pheno_geno_merged-laboratory_typing_method',
#        'pheno_geno_merged-platform', 'pheno_geno_merged-ast_standard',
#        'pheno_geno_merged-gen_antibiotic_ontology', 'pheno_geno_merged-region',
#        'pheno_geno_merged-region_start', 'pheno_geno_merged-region_end',
#        'pheno_geno_merged-strand', 'pheno_geno_merged-id',
#        'pheno_geno_merged-gene_symbol', 'pheno_geno_merged-amr_element_symbol',
#        'pheno_geno_merged-element_type', 'pheno_geno_merged-element_subtype',
#        'pheno_geno_merged-class', 'pheno_geno_merged-subclass',
# ...

# %%
df['pheno_geno_merged-antibiotic_name'].value_counts()
# Out:
# tetracycline    9337
# azithromycin    1851
# erythromycin       2
# Name: pheno_geno_merged-antibiotic_name, dtype: int64

# %%
ng_azithro = df[df['pheno_geno_merged-antibiotic_name'] == 'azithromycin']
ng_tetracycline = df[df['pheno_geno_merged-antibiotic_name'] == 'tetracycline']

# %%
ng_azithro["pheno_geno_merged-resistance_phenotype"].value_counts()
# Out:
# susceptible     1724
# resistant        112
# intermediate      15
# Name: pheno_geno_merged-resistance_phenotype, dtype: int64

# %%
ng_tetracycline["pheno_geno_merged-resistance_phenotype"].value_counts()
# Out:
# resistant       4077
# susceptible     3362
# intermediate    1898
# Name: pheno_geno_merged-resistance_phenotype, dtype: int64
